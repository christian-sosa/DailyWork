# %%
import pandas as pd
import awswrangler as wr

# %%
integrantes_gt = wr.s3.read_parquet("s3://cchc-dw-qa-staging/conecta/integrantes_gt_v2/", dataset=True)
ficha_persona = wr.s3.read_parquet("s3://cchc-dw-qa-staging/conecta/ficha_personas/", dataset=True)

# %%
integrantes_gt
# Out:
#                                         per_nom_0 per_ape_pat_1 per_ape_mat_2  \
# 0               Inversiones Farías Y Farías Ltda.          <NA>          <NA>
# 1      Constructora Absalón Espinosa Y Cía. Ltda.
# 2                                   Fanaloza S.A.
# 3           Obras Subterráneas S.A. Agencia Chile
# 4           Obras Subterráneas S.A. Agencia Chile
# ...                                           ...           ...           ...
# 61194           Inmobiliaria Monte Aconcagua S.A.
# 61195           Inmobiliaria Monte Aconcagua S.A.
# 61196                           Constructora Maga
# 61197                           Constructora Maga
# 61198                                  Ararat SpA
#
#       per_rut_3 per_dv_4                                razon_social  \
# 0      76093010        5           Inversiones Farías Y Farías Ltda.
# 1      79513290        2  Constructora Absalón Espinosa Y Cía. Ltda.
# 2      76144594        4                               Fanaloza S.A.
# ...
